# %%
from PIL import Image
import numpy as np
import sys
import os
import csv
import matplotlib.pyplot as plt

# default format can be changed as needed
def createFileList(myDir, format='.png'):
    fileList = []
    labels = []
    names = []
    keywords = {} # keys and values to be changed as needed
    for root, dirs, files in os.walk(myDir, topdown=True):
        for name in files:
            if name.endswith(format):
                fullName = os.path.join(root, name)
                fileList.append(fullName)
            for keyword in keywords:
                if keyword in name:
                    labels.append(keywords[keyword])
                else:
                    continue
            names.append(name)
    return fileList, labels, names
# load the original image
myFileList, labels, names  = createFileList('/Users/maggie/Code/innovation-lab/generator/images')

i = 0

for file in myFileList:
    img_file = Image.open(file)
    width, height = img_file.size
    format = img_file.format
    mode = img_file.mode
    
    img_grey = img_file.convert('L')
    value = np.asarray(img_grey.getdata(), dtype=int).reshape((width, height))
    value = value.flatten()

    # Convert to NumPy array
    image_array = np.array(img_grey)
    
    # Check the pixel value range
    print("Pixel value range:", image_array.min(), "to", image_array.max())    

    plt.subplot(1, 2, 2)
    plt.imshow(image_array.astype("uint8"))
    plt.title('Grayscale Image')
    plt.axis('off')
    
    plt.show()

    #value = np.append(value,labels[i])
    i +=1
    
    with open("/Users/maggie/Code/innovation-lab/notebooks/images.csv", 'a') as f:
        writer = csv.writer(f)
        writer.writerow(value)
# Out:
# Pixel value range: 82 to 97
# Pixel value range: 47 to 131
# Pixel value range: 65 to 143
# Pixel value range: 63 to 164
# Pixel value range: 11 to 176
# Pixel value range: 36 to 105
# Pixel value range: 43 to 185
# Pixel value range: 70 to 160
# Pixel value range: 147 to 154
# Pixel value range: 147 to 174
# Pixel value range: 59 to 87
# Pixel value range: 151 to 194
# Pixel value range: 35 to 213
# Pixel value range: 134 to 153
# Pixel value range: 42 to 74
# Pixel value range: 130 to 202
# Pixel value range: 126 to 148
# Pixel value range: 35 to 150
# Pixel value range: 77 to 120
# Pixel value range: 118 to 141
# Pixel value range: 96 to 144
# Pixel value range: 49 to 88
# Pixel value range: 18 to 114
# Pixel value range: 16 to 103
# Pixel value range: 125 to 141
# Pixel value range: 138 to 139
# Pixel value range: 184 to 214
# Pixel value range: 119 to 186
# Pixel value range: 18 to 174
# Pixel value range: 51 to 91
# Pixel value range: 25 to 187
# Pixel value range: 127 to 138
# Pixel value range: 128 to 152
# Pixel value range: 86 to 118
# Pixel value range: 1 to 145
# Pixel value range: 111 to 123
# Pixel value range: 122 to 158
# Pixel value range: 29 to 64
# Pixel value range: 19 to 126
# Pixel value range: 8 to 117
# Pixel value range: 135 to 165
# Pixel value range: 102 to 146
# Pixel value range: 99 to 119
# Pixel value range: 146 to 148
# Pixel value range: 46 to 181
# Pixel value range: 19 to 138
# Pixel value range: 51 to 102
# Pixel value range: 55 to 89
# Pixel value range: 123 to 137
# Pixel value range: 79 to 84
# Pixel value range: 108 to 173
# Pixel value range: 55 to 114
# Pixel value range: 56 to 88
# Pixel value range: 0 to 128
# Pixel value range: 19 to 137
# Pixel value range: 153 to 198
# Pixel value range: 41 to 145
# Pixel value range: 187 to 199
# Pixel value range: 136 to 159
# Pixel value range: 101 to 151
# Pixel value range: 83 to 199
# Pixel value range: 34 to 133
# Pixel value range: 162 to 164
# Pixel value range: 135 to 222
# Pixel value range: 35 to 91
# Pixel value range: 19 to 208
# Pixel value range: 0 to 111
# Pixel value range: 65 to 98
# Pixel value range: 54 to 147
# Pixel value range: 109 to 177
# Pixel value range: 110 to 117
# Pixel value range: 26 to 113
# Pixel value range: 33 to 210
# Pixel value range: 0 to 218
# Pixel value range: 17 to 161
# Pixel value range: 7 to 147
# Pixel value range: 2 to 139
# Pixel value range: 87 to 184
# Pixel value range: 71 to 114
# Pixel value range: 41 to 56
# Pixel value range: 26 to 80
# Pixel value range: 19 to 62
# Pixel value range: 11 to 68
# Pixel value range: 198 to 205
# Pixel value range: 203 to 219
# Pixel value range: 7 to 125
# Pixel value range: 84 to 104
# Pixel value range: 66 to 169
# Pixel value range: 82 to 122
# Pixel value range: 49 to 216
# Pixel value range: 0 to 60
# Pixel value range: 8 to 218
# Pixel value range: 29 to 90
# Pixel value range: 16 to 93
# Pixel value range: 51 to 66
# Pixel value range: 64 to 186
# Pixel value range: 91 to 104
# Pixel value range: 24 to 175
# Pixel value range: 0 to 181
# Pixel value range: 5 to 73
# Pixel value range: 0 to 166
# Pixel value range: 48 to 58
# Pixel value range: 68 to 178
# Pixel value range: 20 to 103
# Pixel value range: 63 to 67
# Pixel value range: 47 to 190
# Pixel value range: 34 to 104
# Pixel value range: 7 to 118
# Pixel value range: 0 to 90
# Pixel value range: 158 to 221
# Pixel value range: 80 to 89
# Pixel value range: 0 to 184
# Pixel value range: 0 to 74
# Pixel value range: 43 to 162
# Pixel value range: 27 to 94
# Pixel value range: 77 to 93
# Pixel value range: 78 to 151
# Pixel value range: 66 to 119
# Pixel value range: 3 to 133
# Pixel value range: 15 to 65
# Pixel value range: 119 to 197
# Pixel value range: 90 to 170
# Pixel value range: 92 to 152
# Pixel value range: 59 to 235
# Pixel value range: 14 to 79
# Pixel value range: 7 to 106
# Pixel value range: 69 to 187
# Pixel value range: 67 to 117
# Pixel value range: 64 to 111
# Pixel value range: 96 to 114
# Pixel value range: 15 to 138
# Pixel value range: 15 to 184
# Pixel value range: 190 to 220
# Pixel value range: 80 to 141
# Pixel value range: 108 to 151
# Pixel value range: 94 to 115
# Pixel value range: 2 to 147
# Pixel value range: 0 to 164
# Pixel value range: 57 to 81
# Pixel value range: 10 to 152
# Pixel value range: 62 to 137
# Pixel value range: 60 to 81
# Pixel value range: 77 to 92
# Pixel value range: 2 to 203
# Pixel value range: 6 to 110
# Pixel value range: 0 to 82
# Pixel value range: 91 to 200
# Pixel value range: 150 to 232
# Pixel value range: 152 to 200
# Pixel value range: 95 to 169
# Pixel value range: 2 to 144
# Pixel value range: 59 to 231
# Pixel value range: 0 to 120
# Pixel value range: 62 to 68
# Pixel value range: 57 to 149
# Pixel value range: 70 to 193
# Pixel value range: 47 to 134
# Pixel value range: 45 to 196
# Pixel value range: 86 to 198
# Pixel value range: 18 to 113
# Pixel value range: 1 to 42
# Pixel value range: 31 to 109
# Pixel value range: 10 to 194
# Pixel value range: 91 to 177
# Pixel value range: 121 to 154
# Pixel value range: 189 to 204
# Pixel value range: 56 to 205
# Pixel value range: 116 to 189
# Pixel value range: 192 to 223
# Pixel value range: 131 to 197
# Pixel value range: 177 to 184
# Pixel value range: 70 to 129
# Pixel value range: 47 to 176
# Pixel value range: 14 to 152
# Pixel value range: 0 to 102
# Pixel value range: 15 to 93
# Pixel value range: 86 to 171
# Pixel value range: 38 to 68
# Pixel value range: 36 to 39
# Pixel value range: 28 to 190
# Pixel value range: 6 to 174
# Pixel value range: 52 to 53
# Pixel value range: 109 to 136
# Pixel value range: 47 to 202
# Pixel value range: 139 to 214
# Pixel value range: 0 to 65
# Pixel value range: 9 to 69
# Pixel value range: 0 to 130
# Pixel value range: 33 to 157
# Pixel value range: 8 to 106
# Pixel value range: 144 to 180
# Pixel value range: 85 to 203
# Pixel value range: 93 to 189
# Pixel value range: 149 to 219
# Pixel value range: 193 to 212
# Pixel value range: 16 to 103
# Pixel value range: 135 to 196
# Pixel value range: 116 to 153
# Pixel value range: 14 to 80
# Pixel value range: 0 to 92
# Pixel value range: 8 to 140
# Pixel value range: 84 to 151
# Pixel value range: 102 to 145
# Pixel value range: 89 to 120
# Pixel value range: 160 to 166
# Pixel value range: 58 to 244
# Pixel value range: 70 to 77
# Pixel value range: 117 to 138
# Pixel value range: 21 to 119
# Pixel value range: 106 to 110
# Pixel value range: 7 to 164
# Pixel value range: 58 to 178
# Pixel value range: 81 to 170
# Pixel value range: 155 to 185
# Pixel value range: 3 to 121
# Pixel value range: 0 to 162
# Pixel value range: 0 to 29
# Pixel value range: 72 to 149
# Pixel value range: 115 to 174
# Pixel value range: 64 to 137
# Pixel value range: 47 to 156
# Pixel value range: 0 to 160
# Pixel value range: 29 to 122
# Pixel value range: 3 to 89
# Pixel value range: 161 to 195
# Pixel value range: 25 to 175
# Pixel value range: 84 to 103
# Pixel value range: 23 to 114
# Pixel value range: 48 to 160
# Pixel value range: 163 to 211
# Pixel value range: 79 to 187
# Pixel value range: 64 to 135
# Pixel value range: 52 to 68
# Pixel value range: 123 to 129
# Pixel value range: 28 to 165
# Pixel value range: 11 to 76
# Pixel value range: 93 to 103
# Pixel value range: 83 to 129
# Pixel value range: 9 to 152
# Pixel value range: 0 to 147
# Pixel value range: 15 to 160
# Pixel value range: 48 to 129
# Pixel value range: 156 to 210
# Pixel value range: 122 to 129
# Pixel value range: 153 to 160
# Pixel value range: 183 to 188
# Pixel value range: 110 to 137
# Pixel value range: 27 to 170
# Pixel value range: 20 to 186
# Pixel value range: 0 to 163
# Pixel value range: 95 to 140
# Pixel value range: 154 to 171
# Pixel value range: 73 to 90
# Pixel value range: 49 to 115
# Pixel value range: 56 to 128
# Pixel value range: 82 to 89
